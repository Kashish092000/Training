# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>cProfile in Python</h2>
# </div>
#
#
# cProfile is a built-in python module that can perform profiling. It is the most commonly used profiler currently.
# It gives:
# * Total run time taken by the entire code.
# * The time taken by each individual step. This allows you to compare and find which parts need optimization
# * The number of times certain functions are being called.

# %%
import cProfile

# %% [markdown]
# cProfile provides a simple run() function which is sufficient for most cases. The syntax is cProfile.run(statement, filename=None, sort=-1)

# %%
import numpy as np
cProfile.run("20+10")
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ```ncalls:``` is the number of calls made. When there are two numbers (like 11/9 above), the function recurred. The first value is the total number of calls and the second value is the number of primitive or non-recursive calls.
#
# ```tottime:``` is the total time spent in the given function (excluding time made in calls to sub-functions).
#
# ```percall:``` is the quotient of tottime divided by ncalls.
#
# ```cumtime:``` is the cumulative time spent in this and all subfunctions. This figure is accurate even for recursive functions.
#
# ```percall:``` is the quotient of cumtime divided by primitive calls.
#
# ```filename:```lineno(function): provides the respective data of each function.

# %% [markdown]
# The ```run()``` function can accept two more arguments: a ```filename``` to write the results to a file instead of the stdout, and a ```sort``` argument that specifies how the output should be sorted.
#
# Some of the common ones are ```cumulative``` (for cumulative time), ```time``` (for total time), and ```calls``` (for number of calls).
#
# If you pass a filename and save the results, we may notice that the output is not human-readable. In this case, we need to use the pstats.Stats class to format the results.

# %% [markdown]
# **Profiling on a code that calls other functions**

# %%
def create_array():
  arr=[]
  for i in range(0,400000):
    arr.append(i)
def print_statement():
  print('Array created successfully')

def main():
  create_array()
  print_statement()
if __name__ == '__main__':
    cProfile.run('main()')
# Out:
# Array created successfully
#          400031 function calls in 0.375 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.234    0.234    0.369    0.369 3911947080.py:1(create_array)
#         1    0.000    0.000    0.000    0.000 3911947080.py:5(print_statement)
#         1    0.006    0.006    0.375    0.375 3911947080.py:8(main)
#         1    0.000    0.000    0.375    0.375 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:518(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#         1    0.000    0.000    0.375    0.375 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    400000    0.135    0.000    0.135    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# This output clearly tells you that for i in range(0,400000) is the part where majority of time is spent.

# %% [markdown]
# **Profile class of cProfile**
#
# Although using ```cProfile.run()``` can be sufficient in most cases, The Profile() class of cProfile gives you more precise control

# %%
# How to use Profile class of cProfile
def create_array():
  arr=[]
  for i in range(0,400000):
    arr.append(i)
    
def print_statement():
  print('Array created successfully')

def main():
  create_array()
  print_statement()
    
if __name__ == '__main__':
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('ncalls')
    stats.print_stats()
# Out:
# Array created successfully
#          400029 function calls in 0.222 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    400000    0.081    0.000    0.081    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:429(_is_master_process)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:448(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:518(write)
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\threading.py:553(is_set)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\1392519505.py:7(print_statement)
#         1    0.004    0.004    0.222    0.222 C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\1392519505.py:10(main)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\zmq\sugar\socket.py:543(send)
#         1    0.136    0.136    0.218    0.218 C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\1392519505.py:2(create_array)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:202(schedule)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# The ```pstats``` module can be used to manipulate the results collected by the profiler object. First, create an instance of the stats class using pstats.Stats. Next, use the Stats class to create a statistics object from a profile object through ```ps= pstats.Stats(profiler)```.
# Now, to sort the output by ncalls, use the ```sort_stats()``` method as shown below. Finally to print the output, call the function ```print_stats()``` of stats object.

# %%
# Sort output by Cumulative time
if __name__ == '__main__':
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('cumtime')
    stats.print_stats()
# Out:
# Array created successfully
#          400029 function calls in 0.252 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004    0.252    0.252 C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\1392519505.py:10(main)
#         1    0.155    0.155    0.247    0.247 C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\1392519505.py:2(create_array)
#    400000    0.092    0.000    0.092    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\1392519505.py:7(print_statement)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:518(write)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:448(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:202(schedule)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\zmq\sugar\socket.py:543(send)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:429(_is_master_process)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\iostream.py:90(_event_pipe)
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\threading.py:553(is_set)

# %% [markdown]
# ```enable()``` Start collecting profiling data.Only in cProfile.
#
# ```disable()``` Stop collecting profiling data.Only in cProfile.
#
# ```create_stats()``` Stop collecting profiling data and record the results internallyasthecurrent profile.
#
# ```print_stats(sort=-1)``` Create a Stats object based on the current profile and print the results to stdout.
#
# ```dump_stats(filename)```Write theresults ofthecurrent profiletofilename.
#
# ```run(cmd)``` Profilethe cmd via exec().
#
# ```runctx(cmd,globals,locals)``` Profile the cmd via exec() with the specified global and localenvironment.
#
# ```runcall(func,/,*args,**kwargs)``` Profilefunc(*args,**kwargs)

# %% [markdown]
# Use ```dump_stats()``` method to store it to any file by providing the path.

# %% [markdown]
# Use ```strip_dirs()``` to removes all leading path information from file names.

# %%
# Remove dir names
stats.strip_dirs()
stats.print_stats()
# Out:
#          400029 function calls in 0.252 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 1392519505.py:7(print_statement)
#         1    0.004    0.004    0.252    0.252 1392519505.py:10(main)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#         1    0.155    0.155    0.247    0.247 1392519505.py:2(create_array)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:518(write)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#    400000    0.092    0.000    0.092    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# Observe the difference between the above and previous outputs. The above output is “random”. This is because, after a strip operation, the object has just been initialized and loaded.

# %%
import cProfile, pstats, io
from pstats import SortKey

pr = cProfile.Profile()
pr.enable()
for i in range(10):
    print(i*i)
pr.disable()
s = io.StringIO()
sortby = SortKey.CUMULATIVE
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.strip_dirs()
ps.print_stats()
print(s.getvalue())
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
#          323 function calls in 0.000 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 contextlib.py:82(__init__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:108(__enter__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:117(__exit__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:238(helper)
#        21    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#        21    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#        21    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         2    0.000    0.000    0.000    0.000 traitlets.py:533(get)
#         2    0.000    0.000    0.000    0.000 traitlets.py:564(__get__)
#         2    0.000    0.000    0.000    0.000 ipstruct.py:125(__getattr__)
#         2    0.000    0.000    0.000    0.000 codeop.py:140(__call__)
#         4    0.000    0.000    0.000    0.000 compilerop.py:138(extra_flags)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:1277(user_global_ns)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:3315(compare)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:3377(run_code)
#         2    0.000    0.000    0.000    0.000 hooks.py:103(__call__)
#         2    0.000    0.000    0.000    0.000 hooks.py:168(pre_run_code_hook)
#        21    0.000    0.000    0.000    0.000 socket.py:357(send)
#        21    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#        21    0.000    0.000    0.000    0.000 iostream.py:197(schedule)
#        20    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#        20    0.000    0.000    0.000    0.000 iostream.py:323(_schedule_flush)
#        20    0.000    0.000    0.000    0.000 iostream.py:386(write)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-94bfcea2c938>:8(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-94bfcea2c938>:6(<module>)
#        21    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        21    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ```CUMULATIVE``` which is for the cumulative time spent in a function. the sorting criteria can be in the form of a SortKey enum (added in Python 3.7) or a string (i.e. using 'cumulative' instead of SortKey.CUMULATIVE is also valid). Finally, the results are created and printed to the standard output.

# %%
import cProfile, pstats, io

def profile(fnc):
    
    """A decorator that uses cProfile to profile a function"""
    
    def inner(*args, **kwargs):        
        pr = cProfile.Profile()
        pr.enable()
        retval = fnc(*args, **kwargs)
        pr.disable()
        s = io.StringIO()
        sortby = 'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        return retval
    return inner

# %%
import time
import random
@profile
def get_winning_numbers():
    random.seed()
    for i in range (0,10):
        time.sleep(1) 
        yield random.randint(1,10)

random.seed()
my_number = random.randint(1,10)
print ("my number is " + str(my_number))

for winning_number in get_winning_numbers():
    print(winning_number)
    if my_number == winning_number:
        print ("you win!")
        break
# Out:
# my number is 8
#          1 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# 8
# you win!

# %% [markdown]
# **Visualize Profiling**
# A best tool available at the moment for visualizing data obtained by cProfile module is SnakeViz

# %%
# Installing the module
# !pip install snakeviz
# Out:
# Collecting snakeviz
#   Downloading snakeviz-2.1.1-py2.py3-none-any.whl (282 kB)
#      ------------------------------------ 282.1/282.1 kB 414.4 kB/s eta 0:00:00
# Requirement already satisfied: tornado>=2.0 in c:\users\kashish.sukhwani\appdata\local\programs\python\python310\lib\site-packages (from snakeviz) (6.2)
# Installing collected packages: snakeviz
# Successfully installed snakeviz-2.1.1
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random
# Simple function to print messages 
def print_msg():
    for i in range(10):
        print("Program completed")
# Generate random data
def generate():
    data = [random.randint(0, 99) for p in range(0, 1000)]
    return data
# Function to search 
def search_function(data):
    for i in data:
        if i in [100,200,300,400,500]:
            print("success")
def main():
    data=generate()
    search_function(data)
    print_msg()
# %load_ext snakeviz
# %snakeviz main()
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz
# Program completed
# Program completed
# Program completed
# Program completed
# Program completed
# Program completed
# Program completed
# Program completed
# Program completed
# Program completed
#
# *** Profile stats marshalled to file 'C:\\Users\\KASHIS~1.SUK\\AppData\\Local\\Temp\\tmpexqwtsi8'.
# Embedding SnakeViz in this document...
# <iframe id='snakeviz-60d7d349-c8e7-11ed-8f89-38f3abf9af81' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-60d7d349-c8e7-11ed-8f89-38f3abf9af81").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/C%3A%5CUsers%5CKASHIS~1.SUK%5CAppData%5CLocal%5CTemp%5Ctmpexqwtsi8")</script>

# %% [markdown]
#  **Profiling Linear Regression Model from scikit learn**
#
# Regression problems are very commonly used for various predictive modeling problems. The below code is a standard Linear regression problem using the sklearn library. Let’s print the profiling reports for this code.

# %%
# Function performing linear regression on diabetes dataset
def regression():
    import numpy as np
    from sklearn import datasets, linear_model
    from sklearn.metrics import mean_squared_error, r2_score
    # Load the diabetes dataset
    diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

    # Use only one feature
    diabetes_X = diabetes_X[:, np.newaxis, 2]
    
    # Split the data into training/testing sets
    diabetes_X_train = diabetes_X[:-20]
    diabetes_X_test = diabetes_X[-20:]
    
    # Split the targets into training/testing sets
    diabetes_y_train = diabetes_y[:-20]
    diabetes_y_test = diabetes_y[-20:]
    
    # Create linear regression object
    regr = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regr.fit(diabetes_X_train, diabetes_y_train)
    
    # Make predictions using the testing set
    diabetes_y_pred = regr.predict(diabetes_X_test)
    
# Initialize profile class and call regression() function
profiler = cProfile.Profile()
profiler.enable()
regression()
profiler.disable()
stats = pstats.Stats(profiler).sort_stats('tottime')

# Print the stats report
stats.print_stats()
# Out:
#          606182 function calls (596812 primitive calls) in 48.307 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       129   35.500    0.275   35.501    0.275 {built-in method _imp.create_dynamic}
#       641    8.565    0.013    8.565    0.013 {built-in method io.open_code}
#      2674    1.474    0.001    1.474    0.001 {built-in method nt.stat}
#       641    0.283    0.000    0.283    0.000 {built-in method marshal.loads}
#       644    0.199    0.000    0.199    0.000 {method '__exit__' of '_io._IOBase' objects}
#         2    0.148    0.074    0.148    0.074 {built-in method _ctypes.LoadLibrary}
#      4328    0.139    0.000    0.205    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#       678    0.101    0.000    0.101    0.000 {method 'read' of '_io.BufferedReader' objects}
#     900/2    0.080    0.000   48.309   24.155 {built-in method builtins.exec}
#       399    0.069    0.000    0.192    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\doccer.py:13(docformat)
# 1201/1197    0.063    0.000    0.200    0.000 {built-in method builtins.__build_class__}
#   129/113    0.058    0.000    4.401    0.039 {built-in method _imp.exec_dynamic}
#       953    0.047    0.000    1.519    0.002 <frozen importlib._bootstrap_external>:1536(find_spec)
#        77    0.045    0.001    0.045    0.001 {built-in method nt.listdir}
#       641    0.042    0.000    9.549    0.015 <frozen importlib._bootstrap_external>:950(get_code)
#       416    0.035    0.000    0.060    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\doccer.py:180(indentcount_lines)
#   798/698    0.035    0.000    3.335    0.005 <frozen importlib._bootstrap>:921(_find_spec)
#     12094    0.030    0.000    0.032    0.000 {built-in method builtins.getattr}
#     823/7    0.029    0.000   48.275    6.896 <frozen importlib._bootstrap>:1022(_find_and_load)
#     87812    0.025    0.000    0.025    0.000 {method 'append' of 'list' objects}
#      1282    0.024    0.000    0.126    0.000 <frozen importlib._bootstrap_external>:380(cache_from_source)
#     808/6    0.024    0.000   48.275    8.046 <frozen importlib._bootstrap>:987(_find_and_load_unlocked)
#      9136    0.022    0.000    0.022    0.000 {method 'expandtabs' of 'str' objects}
# 63111/62800    0.021    0.000    0.022    0.000 {built-in method builtins.len}
#      9133    0.021    0.000    0.021    0.000 {method 'splitlines' of 'str' objects}
#     17731    0.020    0.000    0.020    0.000 {method 'startswith' of 'str' objects}
#       641    0.019    0.000    8.884    0.014 <frozen importlib._bootstrap_external>:1070(get_data)
#      1222    0.019    0.000    0.038    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#     778/6    0.018    0.000   48.256    8.043 <frozen importlib._bootstrap>:664(_load_unlocked)
#       593    0.018    0.000    0.051    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2276(_signature_from_function)
#     15596    0.018    0.000    0.020    0.000 {method 'join' of 'str' objects}
#       778    0.018    0.000    0.130    0.000 <frozen importlib._bootstrap>:492(_init_module_attrs)
#      4328    0.016    0.000    0.022    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#     18247    0.016    0.000    0.016    0.000 {method 'endswith' of 'str' objects}
#   989/593    0.016    0.000    0.082    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2371(_signature_from_callable)
#       770    0.015    0.000    0.042    0.000 <frozen importlib._bootstrap_external>:721(spec_from_file_location)
#      1222    0.015    0.000    0.017    0.000 <frozen importlib._bootstrap>:100(acquire)
#    178/61    0.014    0.000    0.040    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:494(_parse)
#       794    0.014    0.000    1.611    0.002 <frozen importlib._bootstrap_external>:1399(_get_spec)
#         3    0.014    0.005    0.014    0.005 {built-in method io.open}
#         7    0.013    0.002    0.018    0.003 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:180(__new__)
#     25540    0.013    0.000    0.015    0.000 {built-in method builtins.isinstance}
#      2670    0.012    0.000    1.485    0.001 <frozen importlib._bootstrap_external>:140(_path_stat)
#        66    0.012    0.000    0.012    0.000 {built-in method builtins.eval}
#     17091    0.012    0.000    0.012    0.000 {method 'rstrip' of 'str' objects}
#      7099    0.012    0.000    0.012    0.000 {method 'replace' of 'str' objects}
#      1222    0.012    0.000    0.015    0.000 <frozen importlib._bootstrap>:125(release)
#     641/6    0.012    0.000   48.255    8.042 <frozen importlib._bootstrap_external>:877(exec_module)
#       995    0.012    0.000    0.012    0.000 {built-in method __new__ of type object at 0x00007FFDCAEA3920}
#        66    0.011    0.000    0.026    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\collections\__init__.py:328(namedtuple)
# 6196/5554    0.011    0.000    7.854    0.001 {built-in method builtins.hasattr}
#         4    0.011    0.003    0.017    0.004 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\constants\_codata.py:1503(parse_constants_2002to2014)
#       641    0.011    0.000    0.019    0.000 <frozen importlib._bootstrap_external>:585(_classify_pyc)
#      5052    0.011    0.000    0.011    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#      1282    0.011    0.000    0.028    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#       641    0.011    0.000    0.298    0.000 <frozen importlib._bootstrap_external>:670(_compile_bytecode)
#      1606    0.010    0.000    0.010    0.000 {built-in method _thread.allocate_lock}
#       845    0.010    0.000    0.022    0.000 <frozen importlib._bootstrap_external>:172(_path_isabs)
#      2232    0.010    0.000    0.017    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2630(__init__)
#      5724    0.010    0.000    0.010    0.000 {method 'rpartition' of 'str' objects}
#     20576    0.010    0.000    0.010    0.000 {built-in method builtins.min}
#     26468    0.009    0.000    0.009    0.000 {method 'lstrip' of 'str' objects}
#      1005    0.009    0.000    0.014    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2913(__init__)
#        77    0.009    0.000    0.063    0.001 <frozen importlib._bootstrap_external>:1587(_fill_cache)
#       613    0.009    0.000    0.018    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\functools.py:35(update_wrapper)
#   778/771    0.008    0.000   35.829    0.046 <frozen importlib._bootstrap>:564(module_from_spec)
#      2516    0.008    0.000    0.012    0.000 <frozen importlib._bootstrap>:404(parent)
#      1001    0.008    0.000    0.843    0.001 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#        16    0.008    0.001    0.008    0.001 {method 'round' of 'numpy.ndarray' objects}
#       388    0.008    0.000    0.067    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:308(getfullargspec_no_self)
#   900/136    0.008    0.000   43.388    0.319 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#       770    0.008    0.000    0.054    0.000 <frozen importlib._bootstrap_external>:1531(_get_spec)
#      1923    0.007    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#       845    0.007    0.000    0.007    0.000 {built-in method nt._path_splitroot}
#      4378    0.007    0.000    0.007    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:234(__next)
#      3846    0.007    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#      1347    0.007    0.000    0.018    0.000 {built-in method builtins.max}
#       770    0.007    0.000    0.081    0.000 <frozen importlib._bootstrap_external>:510(_get_cached)
#    294/56    0.006    0.000    0.016    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:87(_compile)
#      4531    0.006    0.000    0.007    0.000 {built-in method builtins.setattr}
#      3248    0.006    0.000    0.008    0.000 <frozen importlib._bootstrap>:897(__exit__)
#    608/16    0.006    0.000    0.009    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\copy.py:128(deepcopy)
#         1    0.006    0.006    0.472    0.472 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:1(<module>)
#      1411    0.006    0.000    0.086    0.000 <frozen importlib._bootstrap>:391(cached)
#       802    0.006    0.000    0.016    0.000 <frozen importlib._bootstrap>:71(__init__)
#      2409    0.006    0.000    0.006    0.000 {method 'format' of 'str' objects}
#       134    0.006    0.000    0.008    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:3043(_bind)
#       802    0.005    0.000    0.005    0.000 <frozen importlib._bootstrap>:357(__init__)
#       802    0.005    0.000    0.008    0.000 <frozen importlib._bootstrap>:198(cb)
#       953    0.005    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#       202    0.005    0.000    0.006    0.000 {method 'sub' of 're.Pattern' objects}
#    1134/6    0.005    0.000   48.237    8.040 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#      3248    0.005    0.000    0.007    0.000 <frozen importlib._bootstrap>:893(__enter__)
#       641    0.005    0.000    0.235    0.000 <frozen importlib._bootstrap_external>:1089(path_stats)
#       794    0.005    0.000    1.616    0.002 <frozen importlib._bootstrap_external>:1431(find_spec)
#       823    0.005    0.000    0.049    0.000 <frozen importlib._bootstrap>:169(__enter__)
#      3901    0.005    0.000    0.011    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:255(get)
#       977    0.005    0.000    0.075    0.000 <frozen importlib._bootstrap_external>:1356(_path_importer_cache)
#       641    0.005    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:618(_validate_timestamp_pyc)
#      2359    0.005    0.000    0.009    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:359(__call__)
#       108    0.005    0.000    0.199    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:1900(__init__)
#       926    0.004    0.000    0.822    0.001 <frozen importlib._bootstrap_external>:159(_path_isfile)
#        97    0.004    0.000    0.004    0.000 {method 'findall' of 're.Pattern' objects}
#    245/56    0.004    0.000   45.133    0.806 {built-in method builtins.__import__}
#      5272    0.004    0.000    0.004    0.000 {built-in method _imp.acquire_lock}
#      6563    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#        15    0.004    0.000    0.008    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:744(cleandoc)
#      2596    0.004    0.000    0.004    0.000 {method 'rfind' of 'str' objects}
#       328    0.004    0.000    0.010    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:68(read_to_condition)
#      5272    0.004    0.000    0.004    0.000 {built-in method _imp.release_lock}
#       641    0.004    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1040(__init__)
#       408    0.004    0.000    0.019    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\deprecation.py:9(wrap)
#   644/643    0.004    0.000    0.007    0.000 <frozen importlib._bootstrap_external>:542(_check_name_wrapper)
#        36    0.004    0.000    0.004    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.004    0.002    0.004    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\functools.py:853(<lambda>)
#      1059    0.003    0.000    0.007    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:103(make_constraint)
#        26    0.003    0.000    0.003    0.000 {built-in method builtins.compile}
#       125    0.003    0.000    0.005    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:292(_optimize_charset)
#       127    0.003    0.000    0.044    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:674(_construct_argparser)
#       823    0.003    0.000    0.015    0.000 <frozen importlib._bootstrap>:173(__exit__)
#       399    0.003    0.000    0.016    0.000 <frozen importlib._bootstrap>:216(_lock_unlock_module)
#   800/698    0.003    0.000    1.898    0.003 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\_distutils_hack\__init__.py:89(find_spec)
#       593    0.003    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:66(get_annotations)
#       127    0.003    0.000    0.157    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:755(_construct_doc)
#      2127    0.003    0.000    0.003    0.000 {method 'split' of 'str' objects}
#       641    0.003    0.000    0.003    0.000 <frozen importlib._bootstrap>:48(_new_module)
#       396    0.003    0.000    0.008    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:1964(_signature_bound_method)
#       641    0.003    0.000    0.003    0.000 {built-in method _imp._fix_co_filename}
#         1    0.003    0.003    0.005    0.005 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\constants\_codata.py:1514(parse_constants_2018toXXXX)
#       268    0.003    0.000    0.008    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:168(_is_at_section)
#       306    0.003    0.000    0.006    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:89(__setitem__)
#      2807    0.003    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2962(<genexpr>)
#       598    0.003    0.000    0.005    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:612(unwrap)
#       910    0.003    0.000    0.006    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:986(__setattr__)
#        49    0.003    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_deprecated_my_exceptions.py:66(_mk_exception)
#       231    0.003    0.000    0.006    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:146(_type_check)
#      1923    0.003    0.000    0.003    0.000 {built-in method from_bytes}
#       134    0.003    0.000    0.047    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:169(wrapper)
#      1875    0.003    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:165(__getitem__)
#      2444    0.003    0.000    0.003    0.000 {built-in method _thread.get_ident}
#        16    0.003    0.000    0.041    0.003 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\dataclasses.py:882(_process_class)
#       794    0.003    0.000    0.004    0.000 <frozen importlib._bootstrap>:826(find_spec)
#         1    0.003    0.003    0.003    0.003 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\queues.py:161(SimpleQueue)
#      9013    0.003    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2692(kind)
#   338/112    0.003    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:175(getwidth)
#         1    0.002    0.002    0.002    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\linalg\_interface.py:755(IdentityOperator)
#       129    0.002    0.000   35.505    0.275 <frozen importlib._bootstrap_external>:1174(create_module)
#       135    0.002    0.000    0.013    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:28(validate_parameter_constraints)
#      2444    0.002    0.000    0.002    0.000 {method '__exit__' of '_thread.lock' objects}
#      2055    0.002    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:65(eof)
#       510    0.002    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:2244(__init__)
#    135/58    0.002    0.000    0.041    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:436(_parse_sub)
#        75    0.002    0.000    0.070    0.001 <frozen importlib._bootstrap_external>:1343(_path_hooks)
#       146    0.002    0.000    0.002    0.000 {built-in method _abc._abc_init}
#         2    0.002    0.001    0.010    0.005 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:829(loadtxt)
#       171    0.002    0.000    0.070    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\re.py:288(_compile)
#         4    0.002    0.001    0.002    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\ctypes\__init__.py:509(cast)
#       823    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:165(__init__)
#        77    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1616(<setcomp>)
#      2101    0.002    0.000    0.002    0.000 {built-in method nt.fspath}
#        75    0.002    0.000    0.035    0.000 <frozen zipimport>:64(__init__)
#        75    0.002    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:1494(__init__)
#         1    0.002    0.002    0.002    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_ivp\radau.py:1(<module>)
#      4862    0.002    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:723(_floatconv)
#      4730    0.002    0.000    0.002    0.000 {method 'strip' of 'str' objects}
#      3413    0.002    0.000    0.002    0.000 {method 'lower' of 'str' objects}
#         1    0.002    0.002    0.002    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\constants\__init__.py:330(<listcomp>)
#       109    0.002    0.000    0.010    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:1016(__init__)
#        15    0.002    0.000    0.014    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_bunch.py:33(_make_tuple_bunch)
#        63    0.002    0.000    0.024    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\dataclasses.py:412(_create_fn)
#      2187    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#       520    0.002    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:58(seek_next_non_empty_line)
#       794    0.002    0.000    0.002    0.000 {built-in method _imp.is_frozen}
#        97    0.002    0.000    0.013    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\textwrap.py:422(dedent)
#      5258    0.002    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2680(name)
#      1893    0.002    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:44(__getitem__)
#       583    0.002    0.000    0.081    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2991(from_callable)
#       910    0.002    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:935(_is_dunder)
#       975    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#      2356    0.002    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:678(__new__)
#        20    0.002    0.000    0.002    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       643    0.002    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:91(peek)
#       388    0.002    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:330(<listcomp>)
#   381/366    0.002    0.000    0.024    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:306(inner)
#        32    0.002    0.000    0.011    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\arraypad.py:454(_as_pairs)
#      1707    0.002    0.000    0.002    0.000 {method 'partition' of 'str' objects}
#       583    0.002    0.000    0.083    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:3245(signature)
#        28    0.002    0.000    0.009    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_uarray\_backend.py:307(get_defaults)
#      1301    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:81(is_empty)
#      3422    0.001    0.000    0.001    0.000 {method 'values' of 'mappingproxy' objects}
#       671    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:258(__init__)
#   129/113    0.001    0.000    4.403    0.039 <frozen importlib._bootstrap_external>:1182(exec_module)
#        93    0.001    0.000    0.017    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:195(_read_to_next_section)
#       884    0.001    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:1141(convert_row)
#        30    0.001    0.000    0.012    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:218(_parse_param_list)
#       108    0.001    0.000    0.029    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:1966(_attach_methods)
#       134    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2833(apply_defaults)
#        16    0.001    0.000    0.038    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:371(_parse)
#       417    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:345(<genexpr>)
#      2592    0.001    0.000    0.001    0.000 {method 'isidentifier' of 'str' objects}
#        56    0.001    0.000    0.066    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:783(compile)
#        16    0.001    0.000    0.076    0.005 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_axis_nan_policy.py:371(axis_nan_policy_decorator)
#        56    0.001    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:560(_compile_info)
#       322    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:470(__setattr__)
#      1212    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:277(isfunction)
#        75    0.001    0.000    0.032    0.000 <frozen importlib._bootstrap_external>:1628(path_hook_for_FileFinder)
#       144    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:453(_str_param_list)
#         1    0.001    0.001    3.514    3.514 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:1(<module>)
#       412    0.001    0.000    0.005    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:3007(replace)
#       180    0.001    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_internal.py:815(_ufunc_doc_signature_formatter)
#        82    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\weakref.py:165(__setitem__)
#       704    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#      3584    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2999(parameters)
#       380    0.001    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#       549    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\functools.py:65(wraps)
#       127    0.001    0.000    0.025    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:608(__init__)
#       333    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:87(is_unindented)
#        55    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py:146(__init__)
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\getlimits.py:539(smallest_normal)
#       531    0.001    0.000    0.008    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:74(<listcomp>)
#         4    0.001    0.000    0.001    0.000 {built-in method zlib.decompressobj}
#       579    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:173(append)
#        17    0.001    0.000    0.001    0.000 {built-in method builtins.dir}
#       778    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:412(has_location)
#        56    0.001    0.000    0.043    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:944(parse)
#        47    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\dataclasses.py:723(_get_field)
#       796    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:746(find_spec)
#       605    0.001    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#       824    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:250(match)
#      2275    0.001    0.000    0.001    0.000 {built-in method builtins.callable}
#       886    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:974(split_line)
#         1    0.001    0.001   21.162   21.162 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:1(<module>)
#       127    0.001    0.000    0.035    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:660(_attach_argparser_methods)
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadrature.py:26(_copy_func)
#         1    0.001    0.001    0.023    0.023 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\constants\_codata.py:1(<module>)
#        46    0.001    0.000    0.010    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:483(Union)
#         2    0.001    0.000    0.004    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\function_base.py:23(linspace)
#       146    0.001    0.000    0.014    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\abc.py:105(__new__)
#     32/16    0.001    0.000    0.009    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\copy.py:227(_deepcopy_dict)
#         1    0.001    0.001    0.274    0.274 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\testing\_private\utils.py:1(<module>)
#       134    0.001    0.000    0.001    0.000 {method 'match' of 're.Pattern' objects}
#        87    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:206(_collect_type_vars)
#       125    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:265(_compile_charset)
#      1751    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#         1    0.001    0.001    0.300    0.300 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_multivariate.py:1(<module>)
#       614    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:632(_is_wrapper)
#       388    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:335(<listcomp>)
#       252    0.001    0.000    0.009    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:78(read_to_next_empty_line)
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_mannwhitneyu.py:23(__init__)
#    138/69    0.001    0.000    0.022    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      2111    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:2684(default)
#      1143    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#         1    0.001    0.001   23.001   23.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\__init__.py:1(<module>)
#         2    0.001    0.000    0.002    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\getlimits.py:490(_init)
#        11    0.001    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\decorator.py:144(make)
#       641    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1065(get_filename)
#       134    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:179(<listcomp>)
#       614    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:161(__len__)
#      1157    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:226(__init__)
#       388    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:357(<dictcomp>)
#        93    0.001    0.000    0.017    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:206(_read_sections)
#       388    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:340(<listcomp>)
#       388    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:354(<dictcomp>)
#       388    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:350(<listcomp>)
#         1    0.001    0.001    3.526    3.526 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\linalg\__init__.py:1(<module>)
#         1    0.001    0.001    2.639    2.639 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\spatial\distance.py:1(<module>)
#        16    0.001    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:527(__str__)
#        10    0.001    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:1252(getfullargspec)
#       256    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\copy.py:243(_keep_alive)
#        19    0.001    0.000    0.072    0.004 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:3180(__init__)
#         4    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\io\matlab\_miobase.py:135(convert_dtypes)
#      1354    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#       412    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:287(tell)
#       306    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:44(_is_private)
#         7    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:222(<setcomp>)
#        16    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\arraypad.py:129(_set_pad_area)
#         1    0.001    0.001    0.083    0.083 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\constants\__init__.py:1(<module>)
#        24    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:178(__init_subclass__)
#         2    0.001    0.000    0.001    0.000 {method 'newbyteorder' of 'numpy.generic' objects}
#         1    0.001    0.001    0.025    0.025 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_vendor\more_itertools\more.py:1(<module>)
#        56    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:986(__and__)
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_ksstats.py:1(<module>)
#       641    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:874(create_module)
#   176/109    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:1247(__hash__)
#        11    0.001    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\decorator.py:75(__init__)
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_ivp\common.py:1(<module>)
#         1    0.001    0.001    1.862    1.862 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\special\__init__.py:1(<module>)
#        16    0.001    0.000    0.013    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\arraypad.py:529(pad)
#        46    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:267(_remove_dups_flatten)
#       313    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:112(__init__)
#         1    0.001    0.001    6.076    6.076 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\__init__.py:1(<module>)
#       600    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1500(<genexpr>)
#        19    0.001    0.000    0.041    0.002 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:3245(_construct_docstrings)
#       224    0.001    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\copy.py:201(_deepcopy_list)
#        77    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:182(_strip)
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_util.py:375(MapWrapper)
#       109    0.001    0.000    0.004    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:947(__init__)
#       126    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:429(_str_indent)
#         1    0.001    0.001    1.096    1.096 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\dist.py:1(<module>)
#        57    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:225(__init__)
#        78    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:296(_class_escape)
#         1    0.001    0.001    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\ccompiler.py:26(CCompiler)
#         1    0.001    0.001    4.614    4.614 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\spatial\__init__.py:1(<module>)
#       605    0.001    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\abc.py:117(__instancecheck__)
#       108    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_parse.py:356(_escape)
#         5    0.001    0.000    0.001    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#        56    0.001    0.000    0.021    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:622(_code)
#        19    0.001    0.000    0.011    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:3223(_attach_methods)
#       419    0.001    0.000    0.001    0.000 {method 'find' of 'bytearray' objects}
#       280    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:763(<genexpr>)
#       408    0.001    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\deprecation.py:7(_deprecated)
#         1    0.001    0.001    0.003    0.003 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py:1(<module>)
#         1    0.001    0.001    0.009    0.009 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:1(<module>)
#        20    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\utils.py:130(_get_indent)
#         1    0.000    0.000    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\functools.py:884(wrapper)
#         1    0.000    0.000    7.895    7.895 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:1(<module>)
#        75    0.000    0.000    0.025    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#   428/214    0.000    0.000    0.001    0.000 {built-in method builtins.hash}
#        32    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\arraypad.py:109(<genexpr>)
#        16    0.000    0.000    0.009    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\dataclasses.py:529(_init_fn)
#       248    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:137(_type_convert)
#       131    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:395(__init__)
#        15    0.000    0.000    0.002    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\inspect.py:3199(__str__)
#        86    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:319(__init__)
#         1    0.000    0.000    3.775    3.775 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\__init__.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\constants\__init__.py:327(<listcomp>)
#   226/138    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:1037(__hash__)
#   217/211    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       284    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\typing.py:1242(__eq__)
#       129    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1163(__init__)
#     63/53    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:485(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentialevolution.py:402(DifferentialEvolutionSolver)
#       536    0.000    0.000    0.003    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:262(is_satisfied_by)
#         1    0.000    0.000   37.223   37.223 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\__init__.py:1(<module>)
#       284    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:12(_is_descriptor)
#         7    0.000    0.000    0.007    0.001 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nonlin.py:1516(_nonlin_wrapper)
#        29    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\sre_compile.py:437(<listcomp>)
#         9    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:276(_parse_see_also)
#         8    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\types.py:69(new_class)
#       558    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:153(__getitem__)
#        16    0.000    0.000    0.005    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:581(__str__)
#         2    0.000    0.000    0.001    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:4033(get_distribution_names)
#         1    0.000    0.000    0.004    0.004 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_deprecated_my_exceptions.py:98(_mk_common_exceptions)
#         1    0.000    0.000    2.203    2.203 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_discrete_distns.py:1(<module>)
#         1    0.000    0.000    0.325    0.325 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\linalg\_procrustes.py:1(<module>)
#         1    0.000    0.000    0.397    0.397 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\linalg\lapack.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:921(CountVectorizer)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._add_dll_directory}
#        76    0.000    0.000    0.005    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\_lib\_docscrape.py:553(dedent_lines)
#         1    0.000    0.000    0.055    0.055 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_vendor\more_itertools\__init__.py:1(<module>)
#       306    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\enum.py:22(_is_dunder)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\testing\_private\decorators.py:107(skipif)
#         1    0.000    0.000    0.038    0.038 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\cloudpickle\cloudpickle.py:1(<module>)
#         1    0.000    0.000    0.324    0.324 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:1(<module>)
#         1    0.000    0.000    9.249    9.249 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\__init__.py:1(<module>)
#       134    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:185(<dictcomp>)
# ...
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\errors.py:104(CCompilerError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\errors.py:116(LibError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\errors.py:121(LinkError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\errors.py:126(UnknownFileError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:212(Token)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:700(Section)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\unittest\mock.py:1184(Mock)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\unittest\mock.py:2129(MagicMock)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\process_executor.py:951(ShutdownExecutorError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\exceptions.py:92(FitFailedWarning)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_optimize.py:1140(_LineSearchError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\tarfile.py:279(StreamError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\_arff.py:336(BadAttributeFormat)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\_arff.py:349(BadAttributeType)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\importlib\readers.py:11(FileReader)
#         2    0.000    0.000    0.000    0.000 {built-in method io.text_encoding}
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\multiprocessing\context.py:20(TimeoutError)
#         3    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\stride_tricks.py:344(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_base.py:22(SparseEfficiencyWarning)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_arrays.py:68(coo_array)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_arrays.py:76(csr_array)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\errors.py:66(DistutilsSetupError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\errors.py:99(DistutilsByteCompileError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\errors.py:108(PreprocessError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_vendor\packaging\markers.py:33(UndefinedComparison)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\headerregistry.py:397(UniqueSingleAddressHeader)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:507(DotAtomText)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:550(ObsLocalPart)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\exceptions.py:104(SkipTestWarning)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\exceptions.py:113(UndefinedMetricWarning)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\exceptions.py:121(PositiveSpectrumWarning)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_highs\__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\_packaging\__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\tarfile.py:297(SubsequentHeaderError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\_arff.py:386(BadNumericalValue)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\_arff.py:524(Data)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\gzip.py:374(seekable)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\pkg_resources\_vendor\packaging\version.py:491(_parse_local_version)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\stride_tricks.py:25(_maybe_view_as_subclass)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:391(_average_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_data.py:23(_get_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_arrays.py:80(dia_array)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_arrays.py:84(dok_array)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\linalg\_misc.py:9(LinAlgWarning)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:197(Phrase)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:512(NoFoldLiteral)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:685(InvalidParameter)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:854(MessageID)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\tarfile.py:288(TruncatedHeaderError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\tarfile.py:291(EOFHeaderError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\tarfile.py:294(InvalidHeaderError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\io\matlab\_miobase.py:32(MatReadWarning)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\io\arff\_arffread.py:58(ParseArffError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:1523(_IdentityRegressor)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:1533(_IdentityClassifier)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\numeric.py:1247(_rollaxis_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\arraysetops.py:133(_unique_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_sputils.py:313(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:204(CFWSList)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:862(Header)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\unittest\case.py:38(_UnexpectedSuccess)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\unittest\mock.py:2356(AsyncMock)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\io\_harwell_boeing\hb.py:35(LineOverflow)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\_loss\glm_distribution.py:347(PoissonDistribution)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\_loss\glm_distribution.py:354(GammaDistribution)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\importlib\readers.py:108(NamespaceReader)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\dataclasses.py:178(__repr__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\gzip.py:371(writable)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\multiarray.py:1368(may_share_memory)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\email\_header_value_parser.py:208(Atom)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\unittest\case.py:33(_ShouldStop)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:5788(gilbrat_gen)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:8980(FitUniformFixedScaleDataError)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\_arff.py:633(LODData)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\datasets\descr\__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\contextlib.py:426(__exit__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\contextlib.py:735(__enter__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\contextlib.py:738(__exit__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1474(_squeeze_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\linalg\_misc.py:181(_datacopied)
#         1    0.000    0.000    0.000    0.000 <string>:1(__create_fn__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_plot\__init__.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\numeric.py:2176(_allclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\multiarray.py:736(dot)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\nanfunctions.py:1773(_nanstd_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\numeric.py:2255(_isclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\contextlib.py:423(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1751(_ravel_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\stride_tricks.py:362(_broadcast_to_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\datasets\data\__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:2795(_amin_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Kashish.sukhwani\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\nanfunctions.py:1612(_nanvar_dispatcher)

# %%
# %load_ext snakeviz
# %snakeviz regression()
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz
#
# *** Profile stats marshalled to file 'C:\\Users\\KASHIS~1.SUK\\AppData\\Local\\Temp\\tmph83u2lf2'.
# Embedding SnakeViz in this document...
# <iframe id='snakeviz-54df4eb2-c8e8-11ed-a582-38f3abf9af81' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-54df4eb2-c8e8-11ed-a582-38f3abf9af81").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/C%3A%5CUsers%5CKASHIS~1.SUK%5CAppData%5CLocal%5CTemp%5Ctmph83u2lf2")</script>

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>Line Profiler</h2>
# </div>
#
#
# line_profiler will profile the time individual lines of code take to execute
# It help us to moniter small function and able to track python line by line code to know which line of code accupies more time and then we will decide what optimization technique we can use.

# %%
pip install line_profiler
# Out:
# Collecting line_profiler
#   Downloading line_profiler-4.0.3-cp310-cp310-win_amd64.whl (83 kB)
#      -------------------------------------- 83.2/83.2 kB 311.9 kB/s eta 0:00:00
# Installing collected packages: line_profiler
# Successfully installed line_profiler-4.0.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import line_profiler
# %load_ext line_profiler

# %%
from line_profiler import LineProfiler
import random

def do_stuff(numbers):
    s = sum(numbers)
    l = [numbers[i]/43 for i in range(len(numbers))]
    m = ['hello'+str(numbers[i]) for i in range(len(numbers))]

numbers = [random.randint(1,100) for i in range(1000)]
lp = LineProfiler()
lp_wrapper = lp(do_stuff)
lp_wrapper(numbers)
lp.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0018304 s
#
# Could not find file C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\1333878777.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4
#      5         1        184.0    184.0      1.0
#      6         1       6954.0   6954.0     38.0
#      7         1      11166.0  11166.0     61.0

# %% [markdown]
# **Adding Additional Functions to Profile**

# %% [markdown]
# We can add additional functions to be profiled as well. For example, if you had a second called function and you only wrap the calling function, you'll only see the profile results from the calling function.

# %%
from line_profiler import LineProfiler
import random

def do_other_stuff(numbers):
    s = sum(numbers)

def do_stuff(numbers):
    do_other_stuff(numbers)
    l = [numbers[i]/43 for i in range(len(numbers))]
    m = ['hello'+str(numbers[i]) for i in range(len(numbers))]

numbers = [random.randint(1,100) for i in range(1000)]
lp = LineProfiler()
lp_wrapper = lp(do_stuff)
lp_wrapper(numbers)
lp.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0009557 s
#
# Could not find file C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\610329918.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      7
#      8         1        124.0    124.0      1.3
#      9         1       3689.0   3689.0     38.6
#     10         1       5744.0   5744.0     60.1

# %% [markdown]
# The above would only produce the following profile output for the calling function,we can add the additional called function to profile like this:

# %%
from line_profiler import LineProfiler
import random

def do_other_stuff(numbers):
    s = sum(numbers)

def do_stuff(numbers):
    do_other_stuff(numbers)
    l = [numbers[i]/43 for i in range(len(numbers))]
    m = ['hello'+str(numbers[i]) for i in range(len(numbers))]

numbers = [random.randint(1,100) for i in range(1000)]
lp = LineProfiler()
lp.add_function(do_other_stuff)   # add additional function to profile
lp_wrapper = lp(do_stuff)
lp_wrapper(numbers)
lp.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 1.8e-05 s
#
# Could not find file C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\991343514.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4
#      5         1        180.0    180.0    100.0
#
# Total time: 0.0016124 s
#
# Could not find file C:\Users\Kashish.sukhwani\AppData\Local\Temp\ipykernel_14340\991343514.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      7
#      8         1        229.0    229.0      1.4
#      9         1       6794.0   6794.0     42.1
#     10         1       9101.0   9101.0     56.4
